# %% [markdown]
# # (FordBike Ride Sharing Data Investigation)
# ## by (Mustafa Elnaquib)
#
# ## Investigation Overview
#
# > learn about factors affecting trip duration
#
# ## Dataset Overview
#
# > There are 183412 trips in the dataset with 16 features ( duration_sec, start_time, end_time, start_station_id, start_station_name, start_station_latitude, start_station_longitude, end_station_id, end_station_name, end_station_latitude, end_station_longitude, bike_id, user_type, member_birth_year, member_gender, bike_share_for_all_trip) All data is from February 2019, and depeding on station coordinates minimum and maximum; (37.317298, -122.453704) and (37.880222, -121.874119) all in San Francisco area.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv('data_wrangled.csv')

# %% [markdown]
# ## (Trips Duration Average in minutes of different Genders)
#
# > Male riders have the lowest ride average

# %%
df.groupby('member_gender')['duration_min'].mean().plot(kind='bar')
plt.title('Average Duration in minutes of Different Genders')
plt.xlabel('Gender')
plt.ylabel('Duration(min)')
# Out:
# Text(0, 0.5, 'Duration(min)')

# %% [markdown]
# ## (Trips Duration Average in minutes of different Subscribers and Nonsubscribers)
#
# > nonsubscribers take longer trips on average!

# %%
df.groupby('subscribed')['duration_min'].mean().plot(kind='bar');
plt.xticks([False, True], ['Non-subscribers', 'Subscribers']);
plt.title('Average Duration in minutes of Subsribed and Non-subscribed Users')
plt.xlabel('User Subscription')
plt.ylabel('Duration(min)')
# Out:
# Text(0, 0.5, 'Duration(min)')

# %% [markdown]
# ## (Trips Duration Average in minutes of different Week Days)
#
# > riders take longer trips on weekends, which is expected for leisure trips, rather than the work-home trips on work days.

# %%
df.groupby('weekday')['duration_min'].mean().plot(kind='bar');
plt.title('Average Duration in minutes of Trips in different Week Days')
plt.xlabel('Week Days')
plt.ylabel('Duration(min)')
plt.xticks(range(7), ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9cd3821070>,
#   <matplotlib.axis.XTick at 0x7f9cd33b6070>,
#   <matplotlib.axis.XTick at 0x7f9cd3375220>,
#   <matplotlib.axis.XTick at 0x7f9cd3304a00>,
#   <matplotlib.axis.XTick at 0x7f9cd3304f40>,
#   <matplotlib.axis.XTick at 0x7f9cd330d520>,
#   <matplotlib.axis.XTick at 0x7f9cd3304520>],
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ## (Trips Duration in minutes of different Gender and Age)
#
# > Although Male rider have higher ride dutations, in range of 60:80 minutes, they had the lowset average among genders.

# %%
plt.title('Trip duration for different genders and age bands')

plt.subplot(1, 3, 1)
df_male = df[df['member_gender'] == 'Male']
plot_male = plt.scatter(df_male['age'], df_male['duration_min'], alpha=.2)
plt.xlabel('Male Age')
plt.ylabel('Duration(min)')

plt.subplot(1, 3, 2)
df_female = df[df['member_gender'] == 'Female']
plot_female = plt.scatter(df_female['age'], df_female['duration_min'], alpha=.2)
plt.xlabel('Female Age')
plt.ylabel('Duration(min)')

plt.subplot(1, 3, 3)
df_other = df[df['member_gender'] == 'Other']
plot_other = plt.scatter(df_other['age'], df_other['duration_min'], alpha=.2)
plt.xlabel('Other Gender Age')
plt.ylabel('Duration(min)')
# Out:
# Text(0, 0.5, 'Duration(min)')

# %%
# !jupyter nbconvert slide_deck.ipynb --to slides --post serve --no-input --no-prompt --template output_toggle
# Out:
# [NbConvertApp] Converting notebook slide_deck.ipynb to slides
# [NbConvertApp] Writing 389220 bytes to slide_deck.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/slide_deck.slides.html
# Use Control-C to stop this server
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 2.15ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 1.94ms
